# %%
import cv2
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5357b5f7c03c> in <module>
# ----> 1 import cv2
#       2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'

# %%
image= cv2.imread('../parent/images/input.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-af9d93cbc435> in <module>
# ----> 1 image= cv2.imread('../parent/images/input.jpg')
#
# NameError: name 'cv2' is not defined

# %%
image[0,0]
# Out:
# array([12, 18, 31], dtype=uint8)

# %%
gray_img = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
gray_img.shape
# Out:
# (830, 1245)

# %%
image.shape
# Out:
# (830, 1245, 3)

# %%
gray_img[0,0]
# Out:
# 21

# %%
hsv_img = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
hsv_img.shape
# Out:
# (830, 1245, 3)

# %%
hsv_img[0,0]
# Out:
# array([  9, 156,  31], dtype=uint8)

# %%
plt.imshow(image);

# %%
plt.imshow(gray_img);

# %%
plt.imshow(hsv_img);

# %%
cv2.imshow('HSV',image)
cv2.waitKey()
cv2.imshow('h',image[:,:,0])
cv2.waitKey()
cv2.imshow('s',image[:,:,1])
cv2.waitKey()
cv2.imshow('v',image[:,:,2])
cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# 102

# %%
image[:,:,0]
# Out:
# array([[12, 12, 11, ..., 21, 21, 21],
#        [12, 12, 12, ..., 21, 21, 21],
#        [12, 12, 12, ..., 21, 21, 21],
#        ...,
#        [ 4,  4,  3, ..., 18, 19, 20],
#        [ 3,  3,  3, ..., 18, 19, 20],
#        [ 3,  3,  2, ..., 18, 18, 19]], dtype=uint8)
